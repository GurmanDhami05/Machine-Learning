# %%
pip install numpy pandas matplotlib scikit-learn
# Out:
# Requirement already satisfied: numpy in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: pandas in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (2.3.0)
# Requirement already satisfied: matplotlib in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (3.10.3)
# Requirement already satisfied: scikit-learn in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.8.0 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
r = pd.read_csv("Pearson.csv")
r
# Out:
#       Father   Son
# 0       65.0  59.8
# 1       63.3  63.2
# 2       65.0  63.3
# 3       65.8  62.8
# 4       61.1  64.3
# ...      ...   ...
# 1073    67.0  70.8
# 1074    71.3  68.3
# 1075    71.8  69.3
# 1076    70.7  69.3
# 1077    70.3  67.0
#
# [1078 rows x 2 columns]

# %%
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1078 entries, 0 to 1077
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Father  1078 non-null   float64
#  1   Son     1078 non-null   float64
# dtypes: float64(2)
# memory usage: 17.0 KB

# %%
r.describe()
# Out:
#             Father          Son
# count  1078.000000  1078.000000
# mean     67.686827    68.684230
# std       2.745827     2.816194
# min      59.000000    58.500000
# 25%      65.800000    66.900000
# 50%      67.800000    68.600000
# 75%      69.600000    70.500000
# max      75.400000    78.400000

# %%
plt.scatter(r["Father"], r["Son"],color="red")

# %%
x = r.iloc[:, 0:1]
y = r["Son"]

# %%
y
# Out:
# 0       59.8
# 1       63.2
# 2       63.3
# 3       62.8
# 4       64.3
#         ...
# 1073    70.8
# 1074    68.3
# 1075    69.3
# 1076    69.3
# 1077    67.0
# Name: Son, Length: 1078, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y,test_size=0.2, random_state=50)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 862 entries, 264 to 109
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Father  862 non-null    float64
# dtypes: float64(1)
# memory usage: 13.5 KB

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train
# Out:
#       Father
# 264     66.1
# 1013    70.0
# 116     67.7
# 903     64.3
# 955     68.5
# ...      ...
# 1075    71.8
# 229     65.0
# 70      70.0
# 132     72.2
# 109     66.4
#
# [862 rows x 1 columns]

# %%
lr=LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([68.95783892, 64.36755968, 68.55429789, 69.71447836, 71.12687197,
#        70.37023254, 71.53041301, 70.06757676, 67.89854371, 69.2604947 ,
#        68.95783892, 69.10916681, 67.39411742, 66.33482221, 68.20119949,
#        70.77377357, 68.30208475, 71.12687197, 70.42067517, 69.51270784,
#        68.70562578, 68.40297   , 69.6135931 , 70.16846202, 67.84810108,
#        72.64015085, 68.65518315, 69.41182259, 67.6967732 , 67.74721583,
#        67.99942897, 67.64633057, 68.15075686, 69.91624888, 69.2604947 ,
#        71.12687197, 68.80651104, 70.01713413, 67.84810108, 68.85695367,
#        68.80651104, 69.56315047, 67.49500268, 70.52156042, 69.00828155,
#        67.6967732 , 68.85695367, 70.26934728, 66.33482221, 69.71447836,
#        68.45341263, 71.58085564, 67.49500268, 70.21890465, 68.30208475,
#        69.56315047, 65.93128118, 68.50385526, 68.20119949, 67.6967732 ,
#        67.84810108, 67.79765845, 65.77995329, 70.8242162 , 70.57200305,
#        69.21005207, 69.6135931 , 67.89854371, 68.25164212, 68.55429789,
#        68.55429789, 69.81536362, 69.56315047, 69.05872418, 68.50385526,
#        69.51270784, 69.81536362, 65.52774015, 68.65518315, 69.15960944,
#        70.11801939, 69.66403573, 67.74721583, 70.42067517, 67.54544531,
#        69.00828155, 69.31093733, 67.94898634, 69.76492099, 69.86580625,
#        69.71447836, 68.25164212, 67.89854371, 70.16846202, 66.38526484,
#        68.30208475, 67.74721583, 67.74721583, 66.4861501 , 67.39411742,
#        67.89854371, 69.9666915 , 67.44456005, 68.45341263, 70.01713413,
#        68.75606841, 68.30208475, 67.64633057, 69.86580625, 65.32596963,
#        68.30208475, 69.9666915 , 72.28705244, 67.19234691, 69.46226521,
#        71.12687197, 68.35252737, 67.19234691, 69.71447836, 68.70562578,
#        69.56315047, 69.2604947 , 67.34367479, 71.07642934, 66.78880587,
#        69.51270784, 68.90739629, 66.4861501 , 68.50385526, 69.91624888,
#        67.89854371, 67.84810108, 68.80651104, 66.43570747, 68.95783892,
#        69.86580625, 68.85695367, 70.01713413, 66.94013376, 71.27819986,
#        68.50385526, 69.31093733, 67.09146165, 68.25164212, 71.88351141,
#        67.6967732 , 65.42685489, 70.16846202, 67.54544531, 68.25164212,
#        65.98172381, 67.24278954, 69.71447836, 68.15075686, 67.64633057,
#        69.46226521, 69.00828155, 69.2604947 , 68.70562578, 67.29323216,
#        68.20119949, 71.22775723, 66.53659273, 66.8392485 , 69.56315047,
#        68.85695367, 69.31093733, 67.24278954, 69.71447836, 70.16846202,
#        66.33482221, 66.33482221, 69.46226521, 70.62244568, 67.39411742,
#        67.14190428, 71.12687197, 64.97287123, 68.40297   , 71.58085564,
#        68.50385526, 69.56315047, 69.31093733, 69.76492099, 69.31093733,
#        67.34367479, 68.65518315, 67.54544531, 69.05872418, 70.01713413,
#        69.2604947 , 67.14190428, 69.81536362, 67.04101902, 68.30208475,
#        70.52156042, 70.26934728, 67.34367479, 69.46226521, 67.59588794,
#        70.06757676, 67.99942897, 69.41182259, 68.55429789, 67.94898634,
#        69.51270784, 68.10031423, 68.30208475, 68.65518315, 67.89854371,
#        66.38526484, 68.35252737, 68.50385526, 69.9666915 , 67.29323216,
#        68.60474052])

# %%
m = lr.coef_
c = lr.intercept_

# %%
r.head(4)
# Out:
#    Father   Son
# 0    65.0  59.8
# 1    63.3  63.2
# 2    65.0  63.3
# 3    65.8  62.8

# %%
y = m*65.0 + c

# %%
y
# Out:
# array([67.39411742])

# %%
plt.scatter(x_train, y_train, color="red")
plt.scatter(x_test, y_test, color="blue")
plt.plot(x_test, y_pred, color="green")

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.12/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib

# %%
joblib.dump(lr, "model.joblib")
# Out:
# ['model.joblib']
