# %%
pip install numpy matplotlib pandas
# Out:
# Requirement already satisfied: numpy in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: matplotlib in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (3.10.3)
# Requirement already satisfied: pandas in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (2.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('test_energy_data.csv')
df
# Out:
#    Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0    Residential           24563                   15                4
# 1     Commercial           27583                   56               23
# 2     Commercial           45313                    4               44
# 3    Residential           41625                   84               17
# 4    Residential           36720                   58               47
# ..           ...             ...                  ...              ...
# 95    Commercial            1161                   81               11
# 96   Residential           37943                   50               23
# 97    Commercial            1558                   27               29
# 98    Industrial            2145                   56               12
# 99   Residential           42414                   72               24
#
#     Average Temperature Day of Week  Energy Consumption
# 0                 28.52     Weekday             2865.57
# 1                 23.07     Weekend             4283.80
# 2                 33.56     Weekday             5067.83
# 3                 27.39     Weekend             4624.30
# 4                 17.08     Weekday             4820.59
# ..                  ...         ...                 ...
# 95                15.45     Weekend             3010.81
# 96                21.73     Weekend             4248.49
# 97                16.86     Weekend             2843.60
# 98                11.77     Weekend             3348.39
# 99                29.62     Weekday             4722.59
#
# [100 rows x 7 columns]

# %%
df.describe()
# Out:
#        Square Footage  Number of Occupants  Appliances Used  \
# count      100.000000           100.000000       100.000000
# mean     25881.920000            47.230000        26.970000
# std      13711.075264            29.905526        14.237846
# min       1161.000000             2.000000         1.000000
# 25%      14161.000000            21.000000        16.750000
# 50%      27582.500000            47.000000        27.500000
# 75%      38109.500000            73.000000        39.250000
# max      49354.000000            99.000000        49.000000
#
#        Average Temperature  Energy Consumption
# count           100.000000           100.00000
# mean             22.043300          4187.57830
# std               6.957951           832.55985
# min              10.400000          2351.97000
# 25%              15.682500          3621.92500
# 50%              21.970000          4249.39000
# 75%              27.492500          4797.17500
# max              34.710000          6042.56000

# %%
plt.scatter(df['Appliances Used'], df['Energy Consumption'])

# %%
x = df.iloc[:,3:4]
y = df["Energy Consumption"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, 55 to 51
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Appliances Used  80 non-null     int64
# dtypes: int64(1)
# memory usage: 1.2 KB

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
m = lr.coef_
c = lr.intercept_

# %%
df.head(4)
# Out:
#   Building Type  Square Footage  Number of Occupants  Appliances Used  \
# 0   Residential           24563                   15                4
# 1    Commercial           27583                   56               23
# 2    Commercial           45313                    4               44
# 3   Residential           41625                   84               17
#
#    Average Temperature Day of Week  Energy Consumption
# 0                28.52     Weekday             2865.57
# 1                23.07     Weekend             4283.80
# 2                33.56     Weekday             5067.83
# 3                27.39     Weekend             4624.30

# %%
y = m*23 + c
y
# Out:
# array([4120.57449335])

# %%
plt.scatter(x_train, y_train, color="red")
plt.scatter(x_test, y_test, color="blue")
plt.plot(x_test, y_pred, color="green")

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in /home/dhami/Documents/python/juptyer-stuff/.venv/lib/python3.13/site-packages (1.5.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib
joblib.dump(lr, 'energy_model.joblib')
# Out:
# ['energy_model.joblib']
