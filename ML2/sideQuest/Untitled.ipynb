# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pltimport

# %%
df=pd.read_csv("data.csv")
df
# Out:
#       StudyHours ExtraParticipation  PapersPracticed  PreviousMarks  \
# 0            5.0                 No              2.0           69.0
# 1            2.0                Yes              8.0           46.0
# 2            7.0                Yes              5.0           56.0
# 3            6.0                Yes              5.0           42.0
# 4            7.0                 No              6.0           53.0
# ...          ...                ...              ...            ...
# 9995         8.0                Yes              6.0            NaN
# 9996         4.0                 No              3.0           68.0
# 9997         9.0                 No              6.0           48.0
# 9998         NaN                 No              0.0           47.0
# 9999         2.0                 No              6.0           46.0
#
#       SleepingHours  PerformanceIndex
# 0                 8               5.0
# 1                 4              20.0
# ...

# %%
df.describe()
# Out:
#         StudyHours  PapersPracticed  PreviousMarks  SleepingHours  \
# count  8845.000000      9022.000000    9877.000000   10000.000000
# mean      5.512380         4.971736      63.810874       6.530600
# std       2.286963         2.751380      25.025027       1.695863
# min       2.000000         0.000000       4.000000       4.000000
# 25%       4.000000         3.000000      49.000000       5.000000
# 50%       6.000000         5.000000      67.000000       7.000000
# 75%       7.000000         7.000000      84.000000       8.000000
# max       9.000000         9.000000      99.000000       9.000000
#
#        PerformanceIndex
# count       9830.000000
# mean          50.147813
# std           24.002485
# min            0.000000
# 25%           35.000000
# 50%           53.000000
# 75%           69.000000
# max           99.000000

# %%
pip install plotly-express
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df.describe()
# Out:
#         StudyHours  PapersPracticed  PreviousMarks  SleepingHours  \
# count  8845.000000      9022.000000    9877.000000   10000.000000
# mean      5.512380         4.971736      63.810874       6.530600
# std       2.286963         2.751380      25.025027       1.695863
# min       2.000000         0.000000       4.000000       4.000000
# 25%       4.000000         3.000000      49.000000       5.000000
# 50%       6.000000         5.000000      67.000000       7.000000
# 75%       7.000000         7.000000      84.000000       8.000000
# max       9.000000         9.000000      99.000000       9.000000
#
#        PerformanceIndex
# count       9830.000000
# mean          50.147813
# std           24.002485
# min            0.000000
# 25%           35.000000
# 50%           53.000000
# 75%           69.000000
# max           99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   StudyHours          8845 non-null   float64
#  1   ExtraParticipation  10000 non-null  object
#  2   PapersPracticed     9022 non-null   float64
#  3   PreviousMarks       9877 non-null   float64
#  4   SleepingHours       10000 non-null  int64
#  5   PerformanceIndex    9830 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 468.9+ KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7745 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   StudyHours          7745 non-null   float64
#  1   ExtraParticipation  7745 non-null   object
#  2   PapersPracticed     7745 non-null   float64
#  3   PreviousMarks       7745 non-null   float64
#  4   SleepingHours       7745 non-null   int64
#  5   PerformanceIndex    7745 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 423.6+ KB

# %%
import plotly.express as ex
import plotly.io as pio
pio.renderers.default = 'browser'
ex.scatter_3d(df,x="StudyHours",y="PapersPracticed", z="PerformanceIndex")

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe(
)
# Out:
#         StudyHours  PapersPracticed  PreviousMarks  SleepingHours  \
# count  7648.000000      7648.000000    7648.000000    7648.000000
# mean      5.519744         4.981956      64.049555       6.523536
# std       2.284837         2.750073      24.906894       1.700536
# min       2.000000         0.000000       4.000000       4.000000
# 25%       4.000000         3.000000      49.000000       5.000000
# 50%       6.000000         5.000000      67.000000       7.000000
# 75%       7.000000         7.000000      84.000000       8.000000
# max       9.000000         9.000000      99.000000       9.000000
#
#        PerformanceIndex
# count       7648.000000
# mean          51.868593
# std           23.908146
# min            0.000000
# 25%           37.000000
# 50%           54.000000
# 75%           70.000000
# max           99.000000

# %%
x = df.iloc[:,0:3:2]
y = df.iloc[:,-1]
# Out:
# 0        5.0
# 1       20.0
# 2       46.0
# 3       28.0
# 4        4.0
#         ...
# 9993    78.0
# 9994    29.0
# 9996     5.0
# 9997    44.0
# 9999    24.0
# Name: PerformanceIndex, Length: 7648, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6118 entries, 1983 to 9512
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   StudyHours       6118 non-null   float64
#  1   PapersPracticed  6118 non-null   float64
# dtypes: float64(2)
# memory usage: 143.4 KB

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
df.head(10)
# Out:
#     StudyHours ExtraParticipation  PapersPracticed  PreviousMarks  \
# 0          5.0                 No              2.0           69.0
# 1          2.0                Yes              8.0           46.0
# 2          7.0                Yes              5.0           56.0
# 3          6.0                Yes              5.0           42.0
# 4          7.0                 No              6.0           53.0
# 5          9.0                 No              7.0           63.0
# 7          6.0                 No              7.0           96.0
# 8          7.0                 No              8.0           46.0
# 9          7.0                Yes              4.0           79.0
# 10         4.0                Yes              4.0           80.0
#
#     SleepingHours  PerformanceIndex
# 0               8               5.0
# 1               4              20.0
# 2               7              46.0
# 3               8              28.0
# 4               4               4.0
# ...

# %%
c=lr.intercept_
m=lr.coef_
y=(m[0] *7) + (m[1] *8) + c
y
# Out:
# np.float64(56.87758614602971)

# %%
import plotly.io as pio
import plotly.express as px
pio.renderers.default = 'browser'
import plotly.graph_objects as go
x_values = np.linspace(df['StudyHours'].min(),
                       df['StudyHours'].max(), 10)
y_values = np.linspace(df['PapersPracticed'].min(),
                       df['PapersPracticed'].max(), 10)
xGrid, yGrid = np.meshgrid(x_values, y_values)


final = pd.DataFrame({
    "StudyHours": xGrid.ravel(),
    "PapersPracticed": yGrid.ravel()
})
z_final = lr.predict(final).reshape(10, 10)
fig = px.scatter_3d(df, x='StudyHours', y='PapersPracticed', z='PerformanceIndex')
fig.add_trace(go.Surface(x=x_values, y=y_values, z=z_final, colorscale="Viridis",opacity=0.6))

fig.show()

# %%
import joblib
joblib.dump(lr, "model.joblib")
# Out:
# ['model.joblib']

# %%
1
